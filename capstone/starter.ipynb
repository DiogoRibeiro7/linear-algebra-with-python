# %% [markdown]
# # Capstone Starter
# Choose Track A or B and fill in the cells below with analysis and code.

# %% [markdown]
# ## Track A — Least squares & geometry
# - TODO: Load noisy data and visualize it.
# - TODO: Use `least_squares_qr` and explain why QR is needed.
# - TODO: Plot the projection and residual.

# %%
import numpy as np
from linalg_with_python import least_squares, checks

# TODO: load or generate better data
A = np.array([[1.0]])
b = np.array([1.0])
# TODO: replace with real data

# %% [markdown]
# ## Track B — Eigen/SVD
# - TODO: Construct a correlated 2D dataset.
# - TODO: Run SVD or `eigen_2x2` and visualize directions.
# - TODO: Discuss variance explained by singular values.

# %%
from linalg_with_python import eigen

# TODO: create dataset and call eigen.eigen_2x2
X = np.eye(2)
print('placeholders for eigen analysis')

# %% [markdown]
# ## Reflection and figures
# - TODO: Save figures to `assets/figures/` (name them `capstone_trackA.png`, etc.).
# - TODO: Write a short conclusion comparing your residuals or explained variance to your expectations.
